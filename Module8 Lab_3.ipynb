# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaDurgaM/FMML--projects/blob/main/Module8%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-18 04:12:45--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   226MB/s    in 0.3s
#
# 2025-03-18 04:12:47 (226 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25106  1504.07284v1  Building on the success of recent discriminati...    cs
# 40117  1711.04069v1  In this work, we propose a straightforward met...    cs
# 16193  1610.07091v2  Past work in computational sarcasm deals prima...    cs
# 1441   1803.00227v1  Today's high performance deep learning archite...    cs
# 12533  1802.07928v1  Asynchronous distributed machine learning solu...  stat
# ...             ...                                                ...   ...
# 31311  1802.10419v2  Improving information flow in deep networks he...    cs
# 10455   1210.0734v1  Background. Drug-drug interaction (DDI) is a m...  stat
# 8326   1511.04906v3  We investigated how the application of deep le...    cs
# 12250  1710.10733v2  The Madry Lab recently hosted a competition de...  stat
# 27495  1703.08738v1  We address the problem of using hand-drawn ske...    cs
#
#                                                    title  year  \
# 25106            Mid-level Elements for Object Detection  2015
# 40117  Towards ECDSA key derivation from deep embeddi...  2017
# 16193  Automatic Identification of Sarcasm Target: An...  2016
# 1441   WRPN & Apprentice: Methods for Training and In...  2018
# 12533            Asynchronous Byzantine Machine Learning  2018
# ...                                                  ...   ...
# 31311  Convolutional Neural Networks with Alternately...  2018
# 10455  Evaluation of linear classifiers on articles c...  2012
# 8326   Performing Highly Accurate Predictions Through...  2015
# 12250  Attacking the Madry Defense Model with $L_1$-b...  2017
# 27495  Sketch-based Face Editing in Video Using Ident...  2017
#
#                                                 keywords
# 25106  [discriminative, surprisingly, detection, comp...
# 40117  [straightforward, signature, algorithm, embedd...
# 16193  [computational, primarily, detection, introduc...
# 1441   [performance, architectures, parameters, preci...
# 12533  [asynchronous, distributed, solutions, effecti...
# ...                                                  ...
# 31311  [improving, information, difficulties, paramet...
# 10455  [background, interaction, morbidity, mortality...
# 8326   [investigated, application, specifically, conv...
# 12250  [competition, robustness, adversarially, const...
# 27495  [enlarging, modifying, formulated, reconstruct...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25106    [discriminative, surprisingly, detection, comp...
# 40117    [straightforward, signature, algorithm, embedd...
# 16193    [computational, primarily, detection, introduc...
# 1441     [performance, architectures, parameters, preci...
# 12533    [asynchronous, distributed, solutions, effecti...
#                                ...
# 25253    [addresses, synchronization, describes, decomp...
# 27428    [detection, horizontal, applications, introduc...
# 26758    [recognition, particular, automatically, incre...
# 2723     [generating, molecules, properties, important,...
# 7741     [efficient, computational, difficulties, resea...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8819 words.
# Out of those 4560 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de827c84-3d96-44d3-9185-8436a460b1fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de827c84-3d96-44d3-9185-8436a460b1fa")) {                    Plotly.newPlot(                        "de827c84-3d96-44d3-9185-8436a460b1fa",                        [{"x":["surprisingly","effectively","extensive","representation","challenge","approaches","discriminative","interpretable","comparable","pipelines","detection","visualize","experiments","intermediate","categories","addresses","straightforward","providing","representations","embeddings","techniques","minimization","algorithm","applications","technologies","signature","integration","derivation","properties","statistical","viability","extractors","automatic","consisting","introductory","extracting","identification","introduce","classifier","baselines","comparison","computational","primarily","establishes","individually","sentiment","parameters","degradation","requirements","advantage","performance","architectures","accelerator","technique","inference","precision","efficient","stochastic","outperforms","solutions","malicious","information","interestingly","functioning","filtering","components","adjusting","empirically","convergence","functions","essentially","complementary","perfectly","byzantine","asynchronous","distributed","asynchrony","alternative","component","weighting","staleness","additional","resilient","theoretically","effective","leverages","tolerated","guarantees","procedure","environments","competitors","interesting","incorporate","euclidean","geometric","classification","clustering","intrinsic","riemannian","structure","densities","robustness","assumption","traditional","covariance","generalized","differences","framework","resolution","processing","implications","attempted","optimization","successfully","methodology","acquisition","similarities","maximizing","posteriors","deconvolution","unrelated","reconstruction","experimental","approximated","optimizing","denoising","important","algorithmic","distribution","compressive","posterior","variational","trajectories","resonance","tomographic","approximate","addressed","dependencies","confidence","superiority","demonstrate","individual","architecture","community","contextual","fundamental","significant","incorporating","seamlessly","understanding","sequential","computation","achieving","comprehensive","predicted","intrinsically","evaluations","benefiting","recognition","positions","dimension","convolutional","memorization","neighboring","dimensions","intelligence","cognitive","discussion","particular","interpretations","dimensional","presented","engineering","limitations","probabilities","languages","semantics","independence","uncertain","certainty","combination","highlights","concludes","competing","probabilistic","knowledge","relationship","conditional","assumptions","artificial","combining","educational","retrieval","diagnostic","extracted","improving","retrieved","efficiency","transformed","scenarios"],"y":[39,119,153,388,167,423,115,39,92,14,353,15,598,31,73,58,22,91,214,80,357,63,836,431,37,16,46,8,202,164,7,9,191,64,6,64,114,326,151,75,137,291,18,10,14,51,275,20,46,93,860,109,6,247,241,91,426,132,274,159,5,705,18,1,71,96,8,81,114,202,22,33,6,0,12,77,1,92,108,18,0,112,4,49,221,32,2,62,126,93,7,68,57,39,65,488,144,49,13,360,9,106,62,160,19,75,57,578,112,273,33,6,318,79,73,39,25,41,4,7,5,82,373,17,46,44,348,44,208,13,42,53,21,18,1,115,42,45,42,48,583,116,259,70,51,94,238,58,8,164,79,141,77,63,43,6,46,5,393,17,70,345,4,18,46,92,64,38,269,14,181,189,55,59,62,91,92,24,31,7,122,14,6,25,159,352,72,93,61,139,105,10,100,15,99,108,15,155,18,94],"type":"bar"},{"x":["surprisingly","effectively","extensive","representation","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4560,), (4560, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7916666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>Compositional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Operators</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributional</span> <span style='background-color:rgba(0, 255, 0, 0.9368421052631579);'>Semantics</span> <br/><br/><span style=''>This</span> <span style=''>survey</span> <span style=''>presents</span> <span style=''>in</span> <span style=''>some</span> <span style=''>detail</span> <span style=''>the</span> <span style=''>main</span> <span style=''>advances</span> <span style=''>that</span> <span style=''>have</span> <span style=''>been</span> <span style=''>recently</span> <span style=''>taking</span> <span style=''>place</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computational</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Linguistics</span> <span style=''>towards</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>unification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prominent</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>paradigms</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>compositional</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.9368421052631579);'>semantics</span> <span style=''>view</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style=''>models</span> <span style=''>of</span> <span style=''>meaning</span> <span style=''>based</span> <span style=''>on</span> <span style=''>vector</span> <span style=''>spaces</span> <span style=''>After</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.38181818181818183);'>introduction</span> <span style=''>to</span> <span style=''>these</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>I</span> <span style=''>review</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>models</span> <span style=''>that</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>compositionality</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.9368421052631579);'>semantics</span> <span style=''>Then</span> <span style=''>I</span> <span style=''>proceed</span> <span style=''>and</span> <span style=''>present</span> <span style=''>in</span> <span style=''>more</span> <span style=''>detail</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>by</span> <span style=''>Coecke</span> <span style=''>Sadrzadeh</span> <span style=''>and</span> <span style=''>Clark</span> <span style=''>(2010)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>abstract</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>category</span> <span style=''>theory</span> <span style=''>as</span> <span style=''>a</span> <span style=''>more</span> <span style=''>complete</span> <span style=''>example</span> <span style=''>capable</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>ε</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulation</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>Density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>forwards</span> <span style=''>but</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihoods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <span style=''>(ABC)</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>infer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>from</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Traditionally</span> <span style=''>these</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioning</span> <span style=''>on</span> <span style=''>data</span> <span style=''>being</span> <span style=''>inside</span> <span style=''>an</span> <span style=''>epsilon</span> <span style=''>ball</span> <span style=''>around</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>which</span> <span style=''>is</span> <span style=''>only</span> <span style=''>correct</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>epsilonrightarrow0</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>then</span> <span style=''>draw</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>or</span> <span style=''>error</span> <span style=''>bars</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>critically</span> <span style=''>slow</span> <span style=''>down</span> <span style=''>as</span> <span style=''>epsilonrightarrow0</span> <span style=''>and</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>draw</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>a</span> <span style=''>broader</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterio ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>of</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Features</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.4068965517241379);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independent</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reconstructing</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>from</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Features</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>is</span> <span style=''>at</span> <span style=''>most</span> <span style=''>mathcalO(R23</span> <span style=''>exp(</span> <span style=''>D))</span> <span style=''>where</span> <span style=''>D</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>random</span> <span style=''>features</span> <span style=''>and</span> <span style=''>R</span> <span style=''>is</span> <span style=''>the</span> <span style=''>diameter</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>domain</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.30193905817174516);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>Omega(exp(</span> <span style=''>D))</span> <span style=''>for</span> <span style=''>R21</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>prior</span> <span style=''>work</span> <span style=''>we</span> <span style=''>are</span> <span style=''>the</span> <span style=''>first</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>for</span> <span style=''>random</span> <span style=''>Fourier</span> <span style=''>features</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4068965517241379);'>dimensionality</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>As</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>our</span> <span style=''>theory</span> <span style=''>we</span> <span style=''>obtain</span> <span style='background-color:rgba(255, 0, 0, 0.3034825870646766);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>ridge</span> <span style='background-color:rgba(255, 0, 0, 0.5859213250517599);'>regression</span> <span style=''>and</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style=''>Aircraft</span> <span style=''>Engine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diagnostic</span> <span style=''>via</span> <span style=''>Expert</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Indicator</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Aggregation</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Detecting</span> <span style=''>early</span> <span style=''>signs</span> <span style=''>of</span> <span style=''>failures</span> <span style=''>(anomalies)</span> <span style=''>in</span> <span style=''>complex</span> <span style=''>systems</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>main</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>preventive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintenance</span> <span style=''>It</span> <span style=''>allows</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>to</span> <span style=''>avoid</span> <span style=''>actual</span> <span style=''>failures</span> <span style=''>by</span> <span style=''>(re)scheduling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintenance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>in</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintenance</span> <span style=''>costs</span> <span style=''>Aircraft</span> <span style=''>engine</span> <span style=''>health</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style=''>is</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representative</span> <span style=''>example</span> <span style=''>of</span> <span style=''>a</span> <span style=''>field</span> <span style=''>in</span> <span style=''>which</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>is</span> <span style=''>crucial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Manufacturers</span> <span style=''>collect</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>engine</span> <span style=''>related</span> <span style=''>data</span> <span style=''>during</span> <span style=''>flights</span> <span style=''>which</span> <span style=''>are</span> <span style=''>used</span> <span style=''>among</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>to</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalies</span> <span style=''>This</span> <span style=''>article</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>and</span> <span style=''>studies</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>one</span> <span style=''>to</span> <span style=''>build</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>early</span> <span style=''>signs</span> <span style=''>of</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>in</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style=''>builds</span> <span style=''>upon</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expertise</span> <span style=''>and</span> <span style=''>th ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13326187924258664)
# 	segmentation (0.07145409074669525)
# 	challenging (0.10468024294390854)
# 	architecture (0.09253304751697035)
# 	information (0.25187566988210075)
# 	representation (0.13862093604858877)
# 	detection (0.1261164701679171)
# 	convolutional (0.1232583065380493)
# 	different (0.2690246516613076)
# 	recognition (0.14040728831725616)
#
# Some Statistics words are:
# 	algorithm (0.384807596201899)
# 	estimation (0.16391804097951024)
# 	stochastic (0.13943028485757122)
# 	variables (0.14492753623188406)
# 	statistical (0.15892053973013492)
# 	theoretical (0.15292353823088456)
# 	inference (0.19540229885057472)
# 	distribution (0.1874062968515742)
# 	dimensional (0.18840579710144928)
# 	regression (0.19140429785107446)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a35c3fc3-d0a1-4783-ad2e-965b0f87e6a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a35c3fc3-d0a1-4783-ad2e-965b0f87e6a9")) {                    Plotly.newPlot(                        "a35c3fc3-d0a1-4783-ad2e-965b0f87e6a9",                        [{"x":["surprisingly","effectively","extensive","representation","challenge","approaches","discriminative","interpretable","comparable","pipelines","detection","visualize","experiments","intermediate","categories","addresses","straightforward","providing","representations","embeddings","techniques","minimization","algorithm","applications","technologies","signature","integration","derivation","properties","statistical","viability","extractors","automatic","consisting","introductory","extracting","identification","introduce","classifier","baselines","comparison","computational","primarily","establishes","individually","sentiment","parameters","degradation","requirements","advantage","performance","architectures","accelerator","technique","inference","precision","efficient","stochastic","outperforms","solutions","malicious","information","interestingly","functioning","filtering","components","adjusting","empirically","convergence","functions","essentially","complementary","perfectly","byzantine","asynchronous","distributed","asynchrony","alternative","component","weighting","staleness","additional","resilient","theoretically","effective","leverages","tolerated","guarantees","procedure","environments","competitors","interesting","incorporate","euclidean","geometric","classification","clustering","intrinsic","riemannian","structure","densities","robustness","assumption","traditional","covariance","generalized","differences","framework","resolution","processing","implications","attempted","optimization","successfully","methodology","acquisition","similarities","maximizing","posteriors","deconvolution","unrelated","reconstruction","experimental","approximated","optimizing","denoising","important","algorithmic","distribution","compressive","posterior","variational","trajectories","resonance","tomographic","approximate","addressed","dependencies","confidence","superiority","demonstrate","individual","architecture","community","contextual","fundamental","significant","incorporating","seamlessly","understanding","sequential","computation","achieving","comprehensive","predicted","intrinsically","evaluations","benefiting","recognition","positions","dimension","convolutional","memorization","neighboring","dimensions","intelligence","cognitive","discussion","particular","interpretations","dimensional","presented","engineering","limitations","probabilities","languages","semantics","independence","uncertain","certainty","combination","highlights","concludes","competing","probabilistic","knowledge","relationship","conditional","assumptions","artificial","combining","educational","retrieval","diagnostic","extracted","improving","retrieved","efficiency","transformed","scenarios","retrieving","interpreted","evaluating","development","evaluation","complexity","investigate","performed","reconstructs","backprojection","remaining","repeatedly","numerical","algorithms","tomography","iterative","perturbations","quantitatively","verification","thermodynamic","developed","continuously","independent","formalism","variation","responding","characterizing","different","foundation","influence","interaction","experimenting","parameter","variables","behaviors","activation","configuration","characterized","equilibrium","corresponding","validation","minimized","independently","distributions","pathology","determined","interpretability","uncertainty","hippocampus","diagnosis","associated","processes","efficiently ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	byzantine
# 	staleness
# 	conformal
# 	parameterizes
# 	modulating
# 	procrustes
# 	gracefully
# 	selectors
# 	depression
# 	variationally
# 	neuroscientists
# 	exceeding
# 	whitening
# 	thermostats
# 	backfitting
# 	exposition
# 	approachability
# 	equitability
# 	combinatorially
# 	precautions
# Some words which never appear in Statistics papers:
# 	accelerator
# 	backprojection
# 	responding
# 	formations
# 	abstractions
# 	complementing
# 	relatedness
# 	thesaurus
# 	judgements
# 	decidable
# 	decidability
# 	delineate
# 	equalities
# 	satisfiability
# 	undecidable
# 	disparities
# 	discourse
# 	unregistered
# 	neuromorphic
# 	breakthroughs

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0721966205837174e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
